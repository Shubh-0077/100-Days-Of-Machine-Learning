# %% [markdown]
# Syntax to create an Object :
#
# Object name = class name ()

# %%
# eg
L = list()
L
# Out:
# []

# %%
# eg
s = str()
s
# Out:
# ''

# %%
# object literal (Mostly we use)
l = [1,2,3]
l
# Out:
# [1, 2, 3]

# %%
# Class names are writen in Pascal Case: (2 words are written together while 2nd word is captialised)
# HelloWorld

# %% [markdown]
# ATM Balance

# %%
class Atm:

# constructor
    def __init__ (self):
        self.pin = ''
        self.balance = 0

# %%
# Object is needed to access the Class
obj = Atm()

# %%
print(type(obj))
# Out:
# <class '__main__.Atm'>

# %%
obj.
